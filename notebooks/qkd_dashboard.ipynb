# %%
import sys
sys.path.append('../src')

import ipywidgets as widgets
import pandas as pd
import qiskit

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, execute, BasicAer, Aer, transpile, assemble
from qiskit.tools.visualization import plot_histogram

import numpy as np
from numpy.random import randint
import panel as pn


import qkd
pn.extension()
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
def n_bits():
    return pn.widgets.IntInput(name="Number of Qubits", value=10, step=1, start=10, end=1000000)

def decoherence():
    return pn.widgets.FloatSlider(name="Error threshold", value=0, step=0.01, start=0, end=0.5)

def displacement():
    return pn.widgets.FloatSlider(name="Displacement (km)", value=100, step=100, start=100, end=1000)

# %%
style = {'description_width': 'initial'}

bit_value_select = widgets.BoundedIntText(
    value = 100,
    min = 10,
    max = 1000000,
    step = 1,
    description = 'Number of Qubits:',
    disabled = False
)

def select_string_len(n_bits):
    
    print(str(n_bits) + " qubit string generated.")

# %%
widgets.interactive(select_string_len, n_bits=bit_value_select)

# %%
# n_bits = pn.widgets.IntInput(name="Number of Qubits")

qkd.n_bits()
# Out:
# IntInput(name='Number of Qubits')

# %%
pn.Row(
    pn.WidgetBox(n_bits, decoherence, displacement)
)
# Out:
# Row
#     [0] WidgetBox
#         [0] Column
#             [0] Column()
#             [1] Row
#                 [0] IntInput(end=1000000, name='Number of Qubits', start=10, value=10)
#         [1] Column
#             [0] Column()
#             [1] Row
#                 [0] FloatSlider(end=0.5, name='Error threshold', step=0.01)
#         [2] Column
#             [0] Column()
#             [1] Row
#                 [0] FloatSlider(end=1000, name='Displacement (km)', start=100, step=100, value=100)
