# %%
import sys
sys.path.append('../src')

import panel as pn

pn.extension('terminal')

import qkd
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
qkd.dashboard
# Out:
# Nonce:  a5c5858a81fadd9e10b19439fc82cdcf</br>
# MAC:    93b198eb3b821b5258a6b0a47936bcd6</br>
# Row
#     [0] WidgetBox(height=500)
#         [0] TextInput(name='Pre-Shared Key', value='Thirty two very v...)
#         [1] IntInput(end=1000000, name='Number of Qubits', start=10, value=100)
#         [2] FloatSlider(end=0.75, name='Decoherence rate', step=0.01)
#         [3] FloatSlider(end=1000, name='Displacement (km)', start=100, step=100, value=100)
#         [4] Select(name='Target', options=['Bob', 'Test'], value='Bob')
#         [5] Select(name='Authentication Protocol', options=['Poly1305', 'AES', ...], value='Poly1305')
#         [6] Button(clicks=2, name='Generate key')
#         [7] Button(name='Clear terminal')
#         [8] Button(clicks=1, name='Send')
#     [1] Terminal(id=1961023188656)

# %%
qkd.measurement
# Out:
# Nonce:  3c11842c0b592fcbb690a7efb8973d1c</br>
# MAC:    b7385a897a0f28ecf6193bfb10212658</br>
# </br>
# The message or the key is wrong</br>
# Row
#     [0] WidgetBox(height=120)
#         [0] TextInput(name='Authentication Tag', value='Thirty two very v...)
#         [1] Button(clicks=3, name='Measure')
#     [1] Terminal(id=1961023263312)
